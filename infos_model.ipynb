# %%
import json
import matplotlib.pyplot as plt

with open('tic_tac_toe/history.json', 'r') as f:
    history = json.load(f)

plt.plot(history['loss'], label='loss du model o', color='green', linewidth=2, marker='*', )

# %%
import json
import matplotlib.pyplot as plt

with open('tic_tac_toe_2/history.json', 'r') as f:
    history = json.load(f)

plt.plot(history['loss'], label='loss du model o', color='red', linewidth=2, marker='*', )
